# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('sheet1.csv')

# %%
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
display(df.describe())
# df['Gender'].describe()

df[df.values  == "Female"].describe()
# Out:
#         Unit price     Quantity       Tax 5%        Total        cogs  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     55.672130     5.510000    15.379369   322.966749   307.58738
# std      26.494628     2.923431    11.708825   245.885335   234.17651
# min      10.080000     1.000000     0.508500    10.678500    10.17000
# 25%      32.875000     3.000000     5.924875   124.422375   118.49750
# 50%      55.230000     5.000000    12.088000   253.848000   241.76000
# 75%      77.935000     8.000000    22.445250   471.350250   448.90500
# max      99.960000    10.000000    49.650000  1042.650000   993.00000
#
#        gross margin percentage  gross income      Rating
# count             1.000000e+03   1000.000000  1000.00000
# mean              4.761905e+00     15.379369     6.97270
# std               6.131498e-14     11.708825     1.71858
# min               4.761905e+00      0.508500     4.00000
# ...

# %%
df['Gender'].unique().count()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\RAINME~1\AppData\Local\Temp/ipykernel_640/4212634072.py in <module>
# ----> 1 df['Gender'].unique().count()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'count'

# %%
# member = df[['City', 'Customer type', 'gross income']].groupby(['Branch'])

print('===Gender====')

print("Female",df['Gender'].tolist().count('Female'))
print("Male",df['Gender'].tolist().count('Male'))

print('=====City==')

print("Yangon",df['City'].tolist().count('Yangon'))
print("Naypyitaw",df['City'].tolist().count('Naypyitaw'))
print("Mandalay",df['City'].tolist().count('Mandalay'))

# print('====Branch===')

# A - Yangyon
# B - Mandalay
# C - Naypyitaw


# print(df['Branch'].tolist().count('A'))
# print(df['Branch'].tolist().count('B'))
# print(df['Branch'].tolist().count('C'))

print('===Member Type====')

print("Member",df['Customer type'].tolist().count('Member'))
print("Normal",df['Customer type'].tolist().count('Normal'))


print('===Payment Type====')

# df['Payment'].unique()

print("Ewallet",df['Payment'].tolist().count('Ewallet'))
print("Cash",df['Payment'].tolist().count('Cash'))
print("Credit card",df['Payment'].tolist().count('Credit card'))



print('===Payment Type====')

df['Product line'].unique()

print("Health and beauty",df['Product line'].tolist().count('Health and beauty'))
print("Electronic accessories",df['Product line'].tolist().count('Electronic accessories'))
print("Home and lifestyle",df['Product line'].tolist().count('Home and lifestyle'))
print("Sports and travel",df['Product line'].tolist().count('Sports and travel'))
print("Food and beverages",df['Product line'].tolist().count('Food and beverages'))
print("Fashion accessories",df['Product line'].tolist().count('Fashion accessories'))

display(df.groupby(['Product line','Gender',]).size())
# Out:
# ===Gender====
# Female 501
# Male 499
# =====City==
# Yangon 340
# Naypyitaw 328
# Mandalay 332
# ===Member Type====
# Member 501
# Normal 499
# ===Payment Type====
# Ewallet 345
# Cash 344
# Credit card 311
# ===Payment Type====
# Health and beauty 152
# Electronic accessories 170
# Home and lifestyle 160
# Sports and travel 166
# Food and beverages 174
# Fashion accessories 178
# Product line            Gender
# Electronic accessories  Female    84
#                         Male      86
# Fashion accessories     Female    96
#                         Male      82
# Food and beverages      Female    90
#                         Male      84
# Health and beauty       Female    64
#                         Male      88
# Home and lifestyle      Female    79
#                         Male      81
# Sports and travel       Female    88
#                         Male      78
# dtype: int64

# %%
# pd.pivot_table(df,index='Invoice ID')

pivot_df = (pd.pivot_table(df, index = ['Payment']
            ,values=['cogs']
            ,aggfunc={'cogs':np.sum}
                          ))
display(pivot_df)

pivot_df = (pd.pivot_table(df, index = ['City']
            ,values=['cogs']
            ,aggfunc={'cogs':np.sum}
                          ))
display(pivot_df)

pivot_df = (pd.pivot_table(df, index = ['Product line']
            ,values=['cogs']
            ,aggfunc={'cogs':np.sum}
                          ))
display(pivot_df)




pivot_df = (pd.pivot_table(df, index = ['Product line']
            ,values=['cogs']
            ,aggfunc={'cogs':np.average}
                          ))
display(pivot_df)


pivot_df = (pd.pivot_table(df, index = ['Product line']
            ,values=['gross income']
            ,aggfunc={'gross income':np.sum}
                          ))
display(pivot_df)



pivot_df = (pd.pivot_table(df, index = ['Product line', 'City']
            ,values=['cogs']
            ,aggfunc={'cogs':np.sum}
                          ))
display(pivot_df)

pivot_df = (pd.pivot_table(df, index = ['Gender', 'Product line']
            ,values=['cogs']
            ,aggfunc={'cogs':np.sum}
                          ))
display(pivot_df)

pivot_df = (pd.pivot_table(df, index = ['Customer type']
            ,values=['cogs']
            ,aggfunc={'cogs':np.sum}
                          ))
display(pivot_df)



# ,
#                           'Quantity':[np.min,np.max]
# Out:
#                   cogs
# Payment
# Cash         106863.40
# Credit card   95968.64
# Ewallet      104755.34
#                 cogs
# City
# Mandalay   101140.64
# Naypyitaw  105303.53
# Yangon     101143.21
#                             cogs
# Product line
# Electronic accessories  51750.03
# Fashion accessories     51719.90
# Food and beverages      53471.28
# Health and beauty       46851.18
# Home and lifestyle      51297.06
# Sports and travel       52497.93
#                               cogs
# Product line
# Electronic accessories  304.411941
# Fashion accessories     290.561236
# Food and beverages      307.306207
# Health and beauty       308.231447
# Home and lifestyle      320.606625
# Sports and travel       316.252590
#                         gross income
# Product line
# Electronic accessories     2587.5015
# Fashion accessories        2585.9950
# Food and beverages         2673.5640
# Health and beauty          2342.5590
# Home and lifestyle         2564.8530
# ...

# %%
df_CORR = pd.DataFrame()

df_CORR['Rating'] = df['Rating']
df_CORR['Cost of Goods'] = df['cogs']

df_CORR.corr()
# Out:
#                  Rating  Cost of Goods
# Rating         1.000000      -0.036442
# Cost of Goods -0.036442       1.000000

# %%
import seaborn as sns


sns.countplot(df['City'])
plt.title('Which City is the Busiest?')
plt.xlabel('City')
plt.ylabel('Count')
A, B, C = df.City.value_counts()

print('Yangon', A)
print('Nagpyitow', C)
print('Mandalay', B)

plt.figure(dpi=100, figsize =(9,6))
plt.show()
# Out:
# Yangon 340
# Nagpyitow 328
# Mandalay 332
# c:\users\rain megatop\miniconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.countplot(y='Product line', hue = 'Payment', data=df)
plt.xlabel('Count')
plt.ylabel('Product Type')

plt.figure(dpi=100)
plt.show()

# %%
sns.countplot(y='Product line', hue = 'City', data=df)
plt.xlabel('City')
plt.ylabel('Product Type')
plt.figure(figsize=(8, 6))
plt.show()
